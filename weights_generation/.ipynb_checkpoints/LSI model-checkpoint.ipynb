# %%
import pandas as pd
import numpy as np
import spacy
import gensim
import operator
import re
import string

# %%
df_schemes = pd.read_csv('df.csv', encoding='mac_roman')
df_schemes.head()
# Out:
#                        Scheme  \
# 0  Caregiver Training Program
# 1   Caregivers Support Centre
# 2              Family LifeAid
# 3             Food Assistance
# 4                  Assistance
#
#                                          Description  \
# 0  Provides training to caregivers of persons wit...
# 1  Provides support to caregivers of persons with...
# 2  Identified households receive food vouchers ev...
# 3  A self setup group which distributes meal box ...
# 4  Bursaries, bread distribution and food rations...
#
#                      Agency  \
# 0       Caregivers Alliance
# 1       Caregivers Alliance
# 2       Red Cross Singapore
# 3          A Packet of Rice
# 4  Filos Community Services
#
#                                                Image  \
# 0        https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1        https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2   https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3  https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4      https://chidnast.sirv.com/SchemesSG/filos.jpg
#
#                                                 Link  \
# 0          https://www.cal.org.sg/caregiver-training
# 1   https://www.cal.org.sg/caregivers-support-centre
# 2  https://www.redcross.sg/get-assistance/family-...
# 3            https://www.facebook.com/APacketOfRice/
# 4           https://www.filos.sg/services-assistance
#
#                    Who's it for  \
# 0                    Caregivers
# 1                    Caregivers
# 2  Low income,Need food support
# 3  Low income,Need food support
# 4  Low income,Need food support
#
#                                       What it gives  \
# 0             Educational programmes for caregivers
# 1                                    Emotional care
# 2  Financial assistance,Food,Educational programmes
# 3                                              Food
# 4                                  Food,Counselling
#
#                  Scheme Type  \
# 0    Caregiver,Mental Health
# 1    Caregiver,Mental Health
# 2  Low Income,Food,Education
# 3            Low Income,Food
# 4            Low Income,Food
#
#                                   search_booster(WL)  Unnamed: 9  Unnamed: 10  \
# 0  Caregivers feeling overwhelmed. Burnout. Elder...         NaN          NaN
# 1  Caregivers feeling overwhelmed. Burnout. Elder...         NaN          NaN
# 2  needs help to get food, meal, hungry, have not...         NaN          NaN
# 3  Needs help to get food, meal, hungry, have not...         NaN          NaN
# 4  Need to buy daily necessities, food, have not ...         NaN          NaN
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
#Create tag list
#df_schemes['Tags'] = [x for x in df_schemes[df_schemes.columns[5:8]].values]
#df_schemes['Tags'] = df_schemes['Tags'].apply(lambda x: [i for i in x if str(i) != "nan"])
#df_schemes

#Create concatenated column
df_schemes['Combined'] = df_schemes[['Description','search_booster(WL)']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
df_schemes
# Out:
#                                               Scheme  \
# 0                         Caregiver Training Program
# 1                          Caregivers Support Centre
# 2                                     Family LifeAid
# 3                                    Food Assistance
# 4                                         Assistance
# ..                                               ...
# 181  Good Samaritans Reintegration Assistance Scheme
# 182                        Case Management Programme
# 183                     Education Support Programmes
# 184                                 Various Services
# 185           Prison Support Services ñ Kids In Play
#
#                                            Description  \
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 181  Call-in/drop-in centre providing Counselling, ...
# 182  SACA provides holistic support to ex-offenders...
# 183  Educational programmes to assist ex-offenders ...
# 184  Befriending services for families of inmates, ...
# 185  Kids In Play (PSS-KIP) works with children fro...
#
#                                       Agency  \
# 0                        Caregivers Alliance
# 1                        Caregivers Alliance
# 2                        Red Cross Singapore
# 3                           A Packet of Rice
# 4                   Filos Community Services
# ..                                       ...
# 181  Singapore After-Care Association (SACA)
# 182  Singapore After-Care Association (SACA)
# 183  Singapore After-Care Association (SACA)
# 184              Prison Fellowship Singapore
# 185                       The Salvation Army
#
#                                                  Image  \
# 0          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2     https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4        https://chidnast.sirv.com/SchemesSG/filos.jpg
# ..                                                 ...
# 181       https://chidnast.sirv.com/SchemesSG/saca.jpg
# 182       https://chidnast.sirv.com/SchemesSG/saca.jpg
# 183       https://chidnast.sirv.com/SchemesSG/saca.jpg
# 184        https://chidnast.sirv.com/SchemesSG/pfs.jpg
# 185  https://chidnast.sirv.com/SchemesSG/salvationa...
#
#                                                   Link  \
# 0            https://www.cal.org.sg/caregiver-training
# 1     https://www.cal.org.sg/caregivers-support-centre
# 2    https://www.redcross.sg/get-assistance/family-...
# 3              https://www.facebook.com/APacketOfRice/
# 4             https://www.filos.sg/services-assistance
# ..                                                 ...
# 181     https://www.saca.org.sg/call-in-walk-in-centre
# 182            https://www.saca.org.sg/case-management
# 183    https://www.saca.org.sg/education-and-upgrading
# 184                 https://www.pfs.org.sg/family-care
# 185  https://www.salvationarmy.org/singapore/prison...
#
#                               Who's it for  \
# 0                               Caregivers
# 1                               Caregivers
# 2             Low income,Need food support
# 3             Low income,Need food support
# 4             Low income,Need food support
# ..                                     ...
# 181  Ex-offenders,Families of ex-offenders
# 182  Ex-offenders,Families of ex-offenders
# 183                           Ex-offenders
# 184  Ex-offenders,Families of ex-offenders
# 185  Ex-offenders,Families of ex-offenders
#
#                                          What it gives  \
# 0                Educational programmes for caregivers
# 1                                       Emotional care
# 2     Financial assistance,Food,Educational programmes
# 3                                                 Food
# 4                                     Food,Counselling
# ..                                                 ...
# 181         Counselling,Emotional support,Job referral
# 182                               Casework,counselling
# 183  Financial assistance,Vocational training,Emplo...
# 184  Casework,Emotional care,Befriender services,Ed...
# 185  Casework,Emotional care,Befriender services,Ed...
#
#                                           Scheme Type  \
# 0                             Caregiver,Mental Health
# 1                             Caregiver,Mental Health
# 2                           Low Income,Food,Education
# 3                                     Low Income,Food
# 4                                     Low Income,Food
# ..                                                ...
# 181                                       Ex-offender
# 182  Family,Children,Ex-offender,Low Income,Education
# 183  Family,Children,Ex-offender,Low Income,Education
# 184  Family,Children,Ex-offender,Low Income,Education
# 185  Family,Children,Ex-offender,Low Income,Education
#
#                                     search_booster(WL)  Unnamed: 9  \
# 0    Caregivers feeling overwhelmed. Burnout. Elder...         NaN
# 1    Caregivers feeling overwhelmed. Burnout. Elder...         NaN
# 2    needs help to get food, meal, hungry, have not...         NaN
# 3    Needs help to get food, meal, hungry, have not...         NaN
# 4    Need to buy daily necessities, food, have not ...         NaN
# ..                                                 ...         ...
# 181  free tuition, children of ex-offender, childre...         NaN
# 182  free tuition, children of ex-offender, childre...         NaN
# 183  ex-offender want to study, ex-convict want to ...         NaN
# 184  free tuition, children of ex-offender, childre...         NaN
# 185  free tuition, children of ex-offender, childre...         NaN
#
#      Unnamed: 10  Unnamed: 11  \
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 181          NaN          NaN
# 182          NaN          NaN
# 183          NaN          NaN
# 184          NaN          NaN
# 185          NaN          NaN
#
#                                               Combined
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 181  Call-in/drop-in centre providing Counselling, ...
# 182  SACA provides holistic support to ex-offenders...
# 183  Educational programmes to assist ex-offenders ...
# 184  Befriending services for families of inmates, ...
# 185  Kids In Play (PSS-KIP) works with children fro...
#
# [186 rows x 13 columns]

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import string

spacy_nlp = spacy.load('en_core_web_sm')

#create list of punctuations and stopwords
punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

to_delete = ["alone","themselves"]
for elem in to_delete:
    stop_words.discard(elem)
stop_words.add("client")

#function for data cleaning and processing
#This can be further enhanced by adding / removing reg-exps as desired.

def spacy_tokenizer(sentence):
 
    #remove distracting single quotes
    sentence = re.sub('\'','',sentence)

    #replace extra spaces with single space
    sentence = re.sub(' +',' ',sentence)

    #remove unwanted lines starting from special charcters
    sentence = re.sub(r'\n: \'\'.*','',sentence)
    sentence = re.sub(r'\n!.*','',sentence)
    sentence = re.sub(r'^:\'\'.*','',sentence)
    
    #remove non-breaking new line characters
    sentence = re.sub(r'\n',' ',sentence)
    
    #remove punctuations
    sentence = re.sub(r'[^\w\s]',' ',sentence)
    
    #creating token object
    tokens = spacy_nlp(sentence)
    
    #lower, strip and lemmatize
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    
    #remove stopwords, and exclude words less than 2 characters
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    
    #return tokens
    return tokens

# %%
# %time df_schemes['Tags_tokenized'] = df_schemes['Combined'].map(lambda x: spacy_tokenizer(x))

df_schemes
# Out:
# Wall time: 2.82 s
#                                               Scheme  \
# 0                         Caregiver Training Program
# 1                          Caregivers Support Centre
# 2                                     Family LifeAid
# 3                                    Food Assistance
# 4                                         Assistance
# ..                                               ...
# 181  Good Samaritans Reintegration Assistance Scheme
# 182                        Case Management Programme
# 183                     Education Support Programmes
# 184                                 Various Services
# 185           Prison Support Services ñ Kids In Play
#
#                                            Description  \
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 181  Call-in/drop-in centre providing Counselling, ...
# 182  SACA provides holistic support to ex-offenders...
# 183  Educational programmes to assist ex-offenders ...
# 184  Befriending services for families of inmates, ...
# 185  Kids In Play (PSS-KIP) works with children fro...
#
#                                       Agency  \
# 0                        Caregivers Alliance
# 1                        Caregivers Alliance
# 2                        Red Cross Singapore
# 3                           A Packet of Rice
# 4                   Filos Community Services
# ..                                       ...
# 181  Singapore After-Care Association (SACA)
# 182  Singapore After-Care Association (SACA)
# 183  Singapore After-Care Association (SACA)
# 184              Prison Fellowship Singapore
# 185                       The Salvation Army
#
#                                                  Image  \
# 0          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 1          https://chidnast.sirv.com/SchemesSG/CAL.jpg
# 2     https://chidnast.sirv.com/SchemesSG/redcross.jpg
# 3    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 4        https://chidnast.sirv.com/SchemesSG/filos.jpg
# ..                                                 ...
# 181       https://chidnast.sirv.com/SchemesSG/saca.jpg
# 182       https://chidnast.sirv.com/SchemesSG/saca.jpg
# 183       https://chidnast.sirv.com/SchemesSG/saca.jpg
# 184        https://chidnast.sirv.com/SchemesSG/pfs.jpg
# 185  https://chidnast.sirv.com/SchemesSG/salvationa...
#
#                                                   Link  \
# 0            https://www.cal.org.sg/caregiver-training
# 1     https://www.cal.org.sg/caregivers-support-centre
# 2    https://www.redcross.sg/get-assistance/family-...
# 3              https://www.facebook.com/APacketOfRice/
# 4             https://www.filos.sg/services-assistance
# ..                                                 ...
# 181     https://www.saca.org.sg/call-in-walk-in-centre
# 182            https://www.saca.org.sg/case-management
# 183    https://www.saca.org.sg/education-and-upgrading
# 184                 https://www.pfs.org.sg/family-care
# 185  https://www.salvationarmy.org/singapore/prison...
#
#                               Who's it for  \
# 0                               Caregivers
# 1                               Caregivers
# 2             Low income,Need food support
# 3             Low income,Need food support
# 4             Low income,Need food support
# ..                                     ...
# 181  Ex-offenders,Families of ex-offenders
# 182  Ex-offenders,Families of ex-offenders
# 183                           Ex-offenders
# 184  Ex-offenders,Families of ex-offenders
# 185  Ex-offenders,Families of ex-offenders
#
#                                          What it gives  \
# 0                Educational programmes for caregivers
# 1                                       Emotional care
# 2     Financial assistance,Food,Educational programmes
# 3                                                 Food
# 4                                     Food,Counselling
# ..                                                 ...
# 181         Counselling,Emotional support,Job referral
# 182                               Casework,counselling
# 183  Financial assistance,Vocational training,Emplo...
# 184  Casework,Emotional care,Befriender services,Ed...
# 185  Casework,Emotional care,Befriender services,Ed...
#
#                                           Scheme Type  \
# 0                             Caregiver,Mental Health
# 1                             Caregiver,Mental Health
# 2                           Low Income,Food,Education
# 3                                     Low Income,Food
# 4                                     Low Income,Food
# ..                                                ...
# 181                                       Ex-offender
# 182  Family,Children,Ex-offender,Low Income,Education
# 183  Family,Children,Ex-offender,Low Income,Education
# 184  Family,Children,Ex-offender,Low Income,Education
# 185  Family,Children,Ex-offender,Low Income,Education
#
#                                     search_booster(WL)  Unnamed: 9  \
# 0    Caregivers feeling overwhelmed. Burnout. Elder...         NaN
# 1    Caregivers feeling overwhelmed. Burnout. Elder...         NaN
# 2    needs help to get food, meal, hungry, have not...         NaN
# 3    Needs help to get food, meal, hungry, have not...         NaN
# 4    Need to buy daily necessities, food, have not ...         NaN
# ..                                                 ...         ...
# 181  free tuition, children of ex-offender, childre...         NaN
# 182  free tuition, children of ex-offender, childre...         NaN
# 183  ex-offender want to study, ex-convict want to ...         NaN
# 184  free tuition, children of ex-offender, childre...         NaN
# 185  free tuition, children of ex-offender, childre...         NaN
#
#      Unnamed: 10  Unnamed: 11  \
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 181          NaN          NaN
# 182          NaN          NaN
# 183          NaN          NaN
# 184          NaN          NaN
# 185          NaN          NaN
#
#                                               Combined  \
# 0    Provides training to caregivers of persons wit...
# 1    Provides support to caregivers of persons with...
# 2    Identified households receive food vouchers ev...
# 3    A self setup group which distributes meal box ...
# 4    Bursaries, bread distribution and food rations...
# ..                                                 ...
# 181  Call-in/drop-in centre providing Counselling, ...
# 182  SACA provides holistic support to ex-offenders...
# 183  Educational programmes to assist ex-offenders ...
# 184  Befriending services for families of inmates, ...
# 185  Kids In Play (PSS-KIP) works with children fro...
#
#                                         Tags_tokenized
# 0    [provide, training, caregiver, person, mental,...
# 1    [provide, support, caregiver, person, mental, ...
# 2    [identify, household, receive, food, voucher, ...
# 3    [self, setup, group, distribute, meal, box, lo...
# 4    [bursary, bread, distribution, food, ration, g...
# ..                                                 ...
# 181  [drop, centre, provide, counselling, job, refe...
# 182  [saca, provide, holistic, support, offender, a...
# 183  [educational, programme, assist, offender, kee...
# 184  [befriend, service, family, inmate, group, tui...
# 185  [kids, play, pss, kip, work, child, year, age,...
#
# [186 rows x 14 columns]

# %%
Description_to_match = df_schemes['Tags_tokenized']
Description_to_match[0:5]
# Out:
# 0    [provide, training, caregiver, person, mental,...
# 1    [provide, support, caregiver, person, mental, ...
# 2    [identify, household, receive, food, voucher, ...
# 3    [self, setup, group, distribute, meal, box, lo...
# 4    [bursary, bread, distribution, food, ration, g...
# Name: Tags_tokenized, dtype: object

# %%
#Word Cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

series = pd.Series(np.concatenate(Description_to_match)).value_counts()[:100]
wordcloud = WordCloud(background_color='white').generate_from_frequencies(series)

plt.figure(figsize=(15,15), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#build word dictionary

from gensim import corpora

#creating term dictionary
# %time dictionary = corpora.Dictionary(Description_to_match)

#filter out terms which occurs in less than 4 documents and more than 20% of the documents.
#NOTE: Since we have smaller dataset, we will keep this commented for now.

#dictionary.filter_extremes(no_below=4, no_above=0.2)

#list of few which which can be further removed
stoplist = set('hello and if this can would should could tell ask come go')
stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
dictionary.filter_tokens(stop_ids)
dictionary.save('dictionary')
# Out:
# Wall time: 17.9 ms

# %%
#print top 50 items from the dictionary with their unique token-id
dict_tokens = [[[dictionary[key], dictionary.token2id[dictionary[key]]] for key, value in dictionary.items() if key <= 50]]
print (dict_tokens)
# Out:
# [[['anymore', 0], ['burnout', 1], ['caregiver', 2], ['cope', 3], ['elderly', 4], ['feel', 5], ['generation', 6], ['health', 7], ['issue', 8], ['mental', 9], ['overwhelmed', 10], ['parent', 11], ['person', 12], ['provide', 13], ['sandwich', 14], ['stress', 15], ['training', 16], ['support', 17], ['addition', 18], ['advance', 19], ['assessment', 20], ['benefit', 21], ['carry', 22], ['change', 23], ['child', 24], ['childcare', 25], ['chore', 26], ['condition', 27], ['day', 28], ['dire', 29], ['eat', 30], ['ensure', 31], ['family', 32], ['familyí', 33], ['food', 34], ['help', 35], ['household', 36], ['households', 37], ['hungry', 38], ['identify', 39], ['improvement', 40], ['life', 41], ['meal', 42], ['meet', 43], ['money', 44], ['monitor', 45], ['month', 46], ['need', 47], ['opportunity', 48], ['periodic', 49], ['programme', 50]]]

# %%
#Bag of words
corpus = [dictionary.doc2bow(desc) for desc in Description_to_match]
word_frequencies = [[(dictionary[id], frequency) for id, frequency in line] for line in corpus[0:3]]
print(word_frequencies)
# Out:
# [[('anymore', 1), ('burnout', 1), ('caregiver', 2), ('cope', 1), ('elderly', 1), ('feel', 1), ('generation', 1), ('health', 1), ('issue', 1), ('mental', 1), ('overwhelmed', 1), ('parent', 1), ('person', 1), ('provide', 1), ('sandwich', 1), ('stress', 1), ('training', 1)], [('anymore', 1), ('burnout', 1), ('caregiver', 2), ('cope', 1), ('elderly', 1), ('feel', 1), ('generation', 1), ('health', 1), ('issue', 1), ('mental', 1), ('overwhelmed', 1), ('parent', 1), ('person', 1), ('provide', 1), ('sandwich', 1), ('stress', 1), ('support', 1)], [('elderly', 1), ('provide', 1), ('support', 1), ('addition', 1), ('advance', 1), ('assessment', 1), ('benefit', 1), ('carry', 1), ('change', 1), ('child', 3), ('childcare', 1), ('chore', 2), ('condition', 1), ('day', 1), ('dire', 1), ('eat', 1), ('ensure', 1), ('family', 1), ('familyí', 1), ('food', 2), ('help', 3), ('household', 3), ('households', 1), ('hungry', 1), ('identify', 1), ('improvement', 1), ('life', 1), ('meal', 1), ('meet', 1), ('money', 1), ('monitor', 1), ('month', 1), ('need', 5), ('opportunity', 1), ('periodic', 1), ('programme', 1), ('receive', 1), ('review', 1), ('senior', 1), ('storytelle', 1), ('supplementary', 1), ('tuition', 1), ('tutoring', 1), ('voucher', 1), ('young', 1)]]

# %%
#TF IDF and LSI
# %time schemes_tfidf_model = gensim.models.TfidfModel(corpus, id2word=dictionary)
schemes_tfidf_model.save("tfidf.model")
# %time schemes_lsi_model = gensim.models.LsiModel(schemes_tfidf_model[corpus], id2word=dictionary, num_topics=300)
schemes_lsi_model.save("lsi.model")
# Out:
# Wall time: 5.98 ms
# Wall time: 538 ms

# %%
# %time gensim.corpora.MmCorpus.serialize('schemes_tfidf_model_mm', schemes_tfidf_model[corpus])
# %time gensim.corpora.MmCorpus.serialize('schemes_lsi_model_mm',schemes_lsi_model[schemes_tfidf_model[corpus]])
# Out:
# Wall time: 68.8 ms
# Wall time: 218 ms

# %%
#Load indexed corpus
schemes_tfidf_corpus = gensim.corpora.MmCorpus('schemes_tfidf_model_mm')
schemes_lsi_corpus = gensim.corpora.MmCorpus('schemes_lsi_model_mm')

print(schemes_tfidf_corpus)
print(schemes_lsi_corpus)
# Out:
# MmCorpus(186 documents, 1466 features, 4729 non-zero entries)
# MmCorpus(186 documents, 186 features, 34230 non-zero entries)

# %%
from gensim.similarities import MatrixSimilarity

# %time schemes_index = MatrixSimilarity(schemes_lsi_corpus, num_features = schemes_lsi_corpus.num_terms)
# Out:
# Wall time: 87.8 ms

# %%
#Search similarity

from operator import itemgetter

def search_similar_schemes(search_term):
    query_bow = dictionary.doc2bow(spacy_tokenizer(search_term))
    query_tfidf = schemes_tfidf_model[query_bow]
    query_lsi = schemes_lsi_model[query_tfidf]

    schemes_index.num_best = 50

    schemes_list = schemes_index[query_lsi]

    schemes_list.sort(key=itemgetter(1), reverse=True)
    schemes_names = []

    for j, scheme in enumerate(schemes_list):

        schemes_names.append (
            {
                'Relevance': round((scheme[1] * 100),2),
                'Scheme Title': df_schemes['Scheme'][scheme[0]],
                'Description': df_schemes['Description'][scheme[0]]
            }

        )
        if j == (schemes_index.num_best-1):
            break

    return pd.DataFrame(schemes_names, columns=['Relevance','Scheme Title','Description'])

# %%
search_similar_schemes('pregnant teen')
# Out:
#     Relevance                                       Scheme Title  \
# 0       78.56                                HCSA Dayspring SPIN
# 1       61.96                       Pregnancy Crisis and Support
# 2       53.00          Babes - A Helping Hand for Pregnant Teens
# 3       31.48                                        Information
# 4        0.00       e2i - Employment and Employability Institute
# 5        0.00                                Enable IT Programme
# 6        0.00                          Mobile Access for Seniors
# 7        0.00                                   Various services
# 8        0.00                              SINDA Job Care Scheme
# 9        0.00                                   Ulu Pandan Stars
# 10       0.00                                         Assistance
# 11       0.00                                         YMCA FACES
# 12       0.00                          Singapore Hospice Council
# 13       0.00                                   Various services
# 14       0.00                         Pioneer Generation Package
# 15       0.00                                     Assisi Hospice
# 16       0.00                        HIV+ Pregnant Mothers' Fund
# 17       0.00          Medicine Subsidies for HIV/AIDS Sufferers
# 18       0.00                                       Legal Clinic
# 19       0.00                       ComCare Long Term Assistance
# 20       0.00  Transport Subsidy and Assistive Device & Equip...
# 21       0.00                           Services for individuals
# 22       0.00                      Financial Assistance Measures
# 23       0.00                                  Yellow Brick Road
# 24       0.00         Kindergarten Fee Assistance Scheme (KiFAS)
# 25      -0.00                    Childcare & Infant Care Subsidy
# 26      -0.00                               Mutual Help and Care
# 27      -0.00                               Silver Housing Bonus
# 28      -0.00  Subsidies for Government-Funded Intermediate a...
# 29      -0.00  Ministry of Education ñ Financial Assistance S...
# 30      -0.00                          Case Management Programme
# 31      -0.00                         Fresh Start Housing Scheme
# 32      -0.00             Prison Support Services ñ Kids In Play
# 33      -0.00                                   Various Services
# 34      -0.00                                     Project Relate
# 35      -0.00                   Tabung Amal Aidifitri Trust Fund
# 36      -0.00                  Matched Retirement Savings Scheme
# 37      -0.00  CPF Housing Grants for Executive Condominiums ...
# 38      -0.00  Subsidised Haemodialysis and Portable Subsidy ...
# 39      -0.00                    Various Programmes and Services
# 40      -0.00                       Staggered Downpayment Scheme
# 41      -0.00                              Home Access Programme
# 42      -0.00                                     LBKM Bursaries
# 43      -0.00                                     Project LADDER
# 44      -0.00                                   Various services
# 45      -0.00                  COVID-19 - Family Assistance Fund
# 46      -0.00                          Caregivers Support Centre
# 47      -0.00                                    Medical Service
# 48      -0.00                               Care for Family Fund
# 49      -0.00         The Straits Times School Pocket Money Fund
#
#                                           Description
# 0   SPIN empowers single parents to make informed ...
# 1   For emotional support, guidance, help and refe...
# 2   Staff will discuss the various options availab...
# 3   Information on various issues, including contr...
# 4   e2i is the empowering network for workers and ...
# 5   The Enable IT Programme aims to build an inclu...
# 6   Mobile Access for Seniors is a scheme that sup...
# 7   Network for people with dementia and depressio...
# 8   SINDAís Job Care Scheme (SINDA JCS) is to assi...
# 9   The programme collaborates with youth voluntee...
# 10  Bursaries, bread distribution and food rations...
# 11  Short term financial assistance, bridging fund...
# 12  An umbrella body representing organisations th...
# 13  End of life care such as Advance Care Planning...
# 14  Subsidies for outpatient care, MediShield Life...
# 15  Provides compassionate, personalised and quali...
# 16  Assistance for HIV positive mothers who cannot...
# 17  Tzu Chi established cooperation with Communica...
# 18  The legal clinic offers free legal services to...
# 19  Long-term ComCare assistance for those who are...
# 20  Members are provided up to 100% subsidy on a c...
# 21  Suicide intervention, emotional support, mid-c...
# 22  As a safety net, we have Financial Assistance ...
# 23  Childrenís Society works with the caregivers a...
# 24  Means-tested subsidy ranging $21 to $170 to as...
# 25  Subsidy to assist with defraying preschool exp...
# 26  The food ration programme is tasked as additio...
# 27  If you are selling your current flat or privat...
# 28  Subsidies for those who may be eligible for in...
# 29  Help needy Singaporean families reduce their b...
# 30  SACA provides holistic support to ex-offenders...
# 31  The Fresh Start Housing Scheme (Fresh Start) a...
# 32  Kids In Play (PSS-KIP) works with children fro...
# 33  Befriending services for families of inmates, ...
# 34  Project Relate is a Prison referred parenting ...
# 35  TAA Trust Fund (Tabung Amal Aidilfitri Trust F...
# 36  Implemented in 2021 to help senior Singaporean...
# 37  A suite of grants available for Executive Cond...
# 38  The subsidised haemodialysis programme at KDF ...
# 39  Various financial support schemes for medical ...
# 40  You may be able to use the Staggered Downpayme...
# 41  Home Access provides eligible Singaporean fami...
# 42  Various education bursaries for primary to pos...
# 43  Project LADDER reaches out to families of inma...
# 44  Home and shelter for at-risk youth, providing ...
# 45  Covid 19 Family Assistance Fund Fund will go t...
# 46  Provides support to caregivers of persons with...
# 47  Singapore Buddhist Free Clinic provides the ge...
# 48  Many people who are diagnosed with HIV will lo...
# 49  To alleviate the financial burden faced by par...

# %%
import flask
print(flask.__version__)
# Out:
# 1.1.2
