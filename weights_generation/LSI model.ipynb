# %%
import pandas as pd
import numpy as np
import spacy
import gensim
import operator
import re
import string

# %%
df_schemes = pd.read_csv('../df.csv', encoding='mac_roman')
df_schemes.tail()
# Out:
#                               Scheme  \
# 405                      Acacia Home
# 406    Bukit Batok Home for the Aged
# 407  Tembusu Home at Pelangi Village
# 408    Thuja Home at Pelangi Village
# 409                MINDSville@Napiri
#
#                                            Description  \
# 405  A seven-storey building with a 250-bed capacit...
# 406  A three-storey building with a 200-bed capacit...
# 407  A seven-storey building with a 200-bed capacit...
# 408  A four-storey building with a 250-bed capacity...
# 409  Designed to provide professional care, accommo...
#
#                                                 Agency  FSC  \
# 405                     Sathya Sai Social Service (4S)  NaN
# 406                     Sathya Sai Social Service (4S)  NaN
# 407                     Sathya Sai Social Service (4S)  NaN
# 408                     Sathya Sai Social Service (4S)  NaN
# 409  Movement for the Intellectually Disabled of Si...  NaN
#
#                                              Image  \
# 405     https://chidnast.sirv.com/SchemesSG/4s.jpg
# 406     https://chidnast.sirv.com/SchemesSG/4s.jpg
# 407     https://chidnast.sirv.com/SchemesSG/4s.jpg
# 408     https://chidnast.sirv.com/SchemesSG/4s.jpg
# 409  https://chidnast.sirv.com/SchemesSG/minds.jpg
#
#                                                   Link  \
# 405  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 406  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 407  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 408  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 409  https://www.minds.org.sg/for-adults/residentia...
#
#                                           Who's it for  \
# 405                                           Homeless
# 406                                           Homeless
# 407                                           Homeless
# 408                                           Homeless
# 409  Persons with intellectual disabilities (PWIDs)...
#
#                                          What it gives  \
# 405                               Housing,Accomodation
# 406                               Housing,Accomodation
# 407                               Housing,Accomodation
# 408                               Housing,Accomodation
# 409  Housing,Accomodation,Peer support,Social Suppo...
#
#                         Scheme Type  \
# 405                Homeless,Housing
# 406                Homeless,Housing
# 407                Homeless,Housing
# 408                Homeless,Housing
# 409  Housing,Mental Health,Children
#
#                                     search_booster(WL)
# 405  Homeless, no place to stay, runaway from home,...
# 406  Homeless, no place to stay, runaway from home,...
# 407  Homeless, no place to stay, runaway from home,...
# 408  Homeless, no place to stay, runaway from home,...
# 409  caregiving, caring, intellectual disability, I...

# %%
#Create tag list
#df_schemes['Tags'] = [x for x in df_schemes[df_schemes.columns[5:8]].values]
#df_schemes['Tags'] = df_schemes['Tags'].apply(lambda x: [i for i in x if str(i) != "nan"])
#df_schemes

#Create concatenated column
df_schemes['Combined'] = df_schemes[['Description','search_booster(WL)']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
df_schemes
# Out:
#                                        Scheme  \
# 0                            Various services
# 1                        Financial Assistance
# 2                             Food Assistance
# 3    Rehabilitation Centre and Respite Centre
# 4                            Various Services
# ..                                        ...
# 405                               Acacia Home
# 406             Bukit Batok Home for the Aged
# 407           Tembusu Home at Pelangi Village
# 408             Thuja Home at Pelangi Village
# 409                         MINDSville@Napiri
#
#                                            Description  \
# 0    Information relating to social service and ref...
# 1    Cancer treatment can place a heavy financial b...
# 2    A self setup group which distributes meal box ...
# 3    Provides Occupational Therapy, Physiotherapy a...
# 4    We prepare educational programs (IT Training) ...
# ..                                                 ...
# 405  A seven-storey building with a 250-bed capacit...
# 406  A three-storey building with a 200-bed capacit...
# 407  A seven-storey building with a 200-bed capacit...
# 408  A four-storey building with a 250-bed capacity...
# 409  Designed to provide professional care, accommo...
#
#                                                 Agency  FSC  \
# 0                            @27 Family Service Centre  Yes
# 1               365 Cancer Prevention Society (365CPS)  NaN
# 2                                     A Packet of Rice  NaN
# 3    Abilities Beyond Limitations and Expectations ...  NaN
# 4                                   Acronis Foundation  NaN
# ..                                                 ...  ...
# 405                     Sathya Sai Social Service (4S)  NaN
# 406                     Sathya Sai Social Service (4S)  NaN
# 407                     Sathya Sai Social Service (4S)  NaN
# 408                     Sathya Sai Social Service (4S)  NaN
# 409  Movement for the Intellectually Disabled of Si...  NaN
#
#                                                  Image  \
# 0        https://chidnast.sirv.com/SchemesSG/27fsc.jpg
# 1       https://chidnast.sirv.com/SchemesSG/365cps.jpg
# 2    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 3         https://chidnast.sirv.com/SchemesSG/able.jpg
# 4      https://chidnast.sirv.com/SchemesSG/acronis.jpg
# ..                                                 ...
# 405         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 406         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 407         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 408         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 409      https://chidnast.sirv.com/SchemesSG/minds.jpg
#
#                                                   Link  \
# 0                            https://www.27fsc.org.sg/
# 1    https://365cps.org.sg/portfolio/financial-supp...
# 2              https://www.facebook.com/APacketOfRice/
# 3                             https://www.able-sg.org/
# 4       https://acronis.org/rehabilitation-of-inmates/
# ..                                                 ...
# 405  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 406  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 407  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 408  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 409  https://www.minds.org.sg/for-adults/residentia...
#
#                                           Who's it for  \
# 0                                             Families
# 1                                      Cancer patients
# 2                         Low income,Need food support
# 3    Persons with disabilities (PWDs),Special needs...
# 4                                         Ex-offenders
# ..                                                 ...
# 405                                           Homeless
# 406                                           Homeless
# 407                                           Homeless
# 408                                           Homeless
# 409  Persons with intellectual disabilities (PWIDs)...
#
#                                          What it gives  \
# 0                                 Counselling,Casework
# 1            Financial assistance for cancer treatment
# 2                                                 Food
# 3    Occupational therapy,Physiotherapy,Educational...
# 4            Vocational training,Employment assistance
# ..                                                 ...
# 405                               Housing,Accomodation
# 406                               Housing,Accomodation
# 407                               Housing,Accomodation
# 408                               Housing,Accomodation
# 409  Housing,Accomodation,Peer support,Social Suppo...
#
#                                            Scheme Type  \
# 0                                    Low Income,Family
# 1                                Low Income,Healthcare
# 2                                      Low Income,Food
# 3    Disability,Family,Transport,Healthcare,Mental ...
# 4                         Prison and Ex-offenders,Work
# ..                                                 ...
# 405                                   Homeless,Housing
# 406                                   Homeless,Housing
# 407                                   Homeless,Housing
# 408                                   Homeless,Housing
# 409                     Housing,Mental Health,Children
#
#                                     search_booster(WL)  \
# 0    social service, individuals, families, casewor...
# 1                         See doctor, cancer, oncology
# 2    Needs help to get food, meal, hungry, have not...
# 3    rehabilitation, occupational therapy, physioth...
# 4    ex-convict need job, ex-convict skills trainin...
# ..                                                 ...
# 405  Homeless, no place to stay, runaway from home,...
# 406  Homeless, no place to stay, runaway from home,...
# 407  Homeless, no place to stay, runaway from home,...
# 408  Homeless, no place to stay, runaway from home,...
# 409  caregiving, caring, intellectual disability, I...
#
#                                               Combined
# 0    Information relating to social service and ref...
# 1    Cancer treatment can place a heavy financial b...
# 2    A self setup group which distributes meal box ...
# 3    Provides Occupational Therapy, Physiotherapy a...
# 4    We prepare educational programs (IT Training) ...
# ..                                                 ...
# 405  A seven-storey building with a 250-bed capacit...
# 406  A three-storey building with a 200-bed capacit...
# 407  A seven-storey building with a 200-bed capacit...
# 408  A four-storey building with a 250-bed capacity...
# 409  Designed to provide professional care, accommo...
#
# [410 rows x 11 columns]

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import string

spacy_nlp = spacy.load('en_core_web_sm')

#create list of punctuations and stopwords
punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

to_delete = ["alone","themselves"]
for elem in to_delete:
    stop_words.discard(elem)
stop_words.add("client")

#function for data cleaning and processing
#This can be further enhanced by adding / removing reg-exps as desired.

def spacy_tokenizer(sentence):
 
    #remove distracting single quotes
    sentence = re.sub('\'','',sentence)

    #replace extra spaces with single space
    sentence = re.sub(' +',' ',sentence)

    #remove unwanted lines starting from special charcters
    sentence = re.sub(r'\n: \'\'.*','',sentence)
    sentence = re.sub(r'\n!.*','',sentence)
    sentence = re.sub(r'^:\'\'.*','',sentence)
    
    #remove non-breaking new line characters
    sentence = re.sub(r'\n',' ',sentence)
    
    #remove punctuations
    sentence = re.sub(r'[^\w\s]',' ',sentence)
    
    #creating token object
    tokens = spacy_nlp(sentence)
    
    #lower, strip and lemmatize
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    
    #remove stopwords, and exclude words less than 2 characters
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    
    #return tokens
    return tokens

# %%
# %time df_schemes['Tags_tokenized'] = df_schemes['Combined'].map(lambda x: spacy_tokenizer(x))

df_schemes
# Out:
# Wall time: 8.66 s
#                                        Scheme  \
# 0                            Various services
# 1                        Financial Assistance
# 2                             Food Assistance
# 3    Rehabilitation Centre and Respite Centre
# 4                            Various Services
# ..                                        ...
# 405                               Acacia Home
# 406             Bukit Batok Home for the Aged
# 407           Tembusu Home at Pelangi Village
# 408             Thuja Home at Pelangi Village
# 409                         MINDSville@Napiri
#
#                                            Description  \
# 0    Information relating to social service and ref...
# 1    Cancer treatment can place a heavy financial b...
# 2    A self setup group which distributes meal box ...
# 3    Provides Occupational Therapy, Physiotherapy a...
# 4    We prepare educational programs (IT Training) ...
# ..                                                 ...
# 405  A seven-storey building with a 250-bed capacit...
# 406  A three-storey building with a 200-bed capacit...
# 407  A seven-storey building with a 200-bed capacit...
# 408  A four-storey building with a 250-bed capacity...
# 409  Designed to provide professional care, accommo...
#
#                                                 Agency  FSC  \
# 0                            @27 Family Service Centre  Yes
# 1               365 Cancer Prevention Society (365CPS)  NaN
# 2                                     A Packet of Rice  NaN
# 3    Abilities Beyond Limitations and Expectations ...  NaN
# 4                                   Acronis Foundation  NaN
# ..                                                 ...  ...
# 405                     Sathya Sai Social Service (4S)  NaN
# 406                     Sathya Sai Social Service (4S)  NaN
# 407                     Sathya Sai Social Service (4S)  NaN
# 408                     Sathya Sai Social Service (4S)  NaN
# 409  Movement for the Intellectually Disabled of Si...  NaN
#
#                                                  Image  \
# 0        https://chidnast.sirv.com/SchemesSG/27fsc.jpg
# 1       https://chidnast.sirv.com/SchemesSG/365cps.jpg
# 2    https://chidnast.sirv.com/SchemesSG/apacketofr...
# 3         https://chidnast.sirv.com/SchemesSG/able.jpg
# 4      https://chidnast.sirv.com/SchemesSG/acronis.jpg
# ..                                                 ...
# 405         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 406         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 407         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 408         https://chidnast.sirv.com/SchemesSG/4s.jpg
# 409      https://chidnast.sirv.com/SchemesSG/minds.jpg
#
#                                                   Link  \
# 0                            https://www.27fsc.org.sg/
# 1    https://365cps.org.sg/portfolio/financial-supp...
# 2              https://www.facebook.com/APacketOfRice/
# 3                             https://www.able-sg.org/
# 4       https://acronis.org/rehabilitation-of-inmates/
# ..                                                 ...
# 405  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 406  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 407  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 408  https://www.4s.org.sg/Welfare-Homes-Singapore-...
# 409  https://www.minds.org.sg/for-adults/residentia...
#
#                                           Who's it for  \
# 0                                             Families
# 1                                      Cancer patients
# 2                         Low income,Need food support
# 3    Persons with disabilities (PWDs),Special needs...
# 4                                         Ex-offenders
# ..                                                 ...
# 405                                           Homeless
# 406                                           Homeless
# 407                                           Homeless
# 408                                           Homeless
# 409  Persons with intellectual disabilities (PWIDs)...
#
#                                          What it gives  \
# 0                                 Counselling,Casework
# 1            Financial assistance for cancer treatment
# 2                                                 Food
# 3    Occupational therapy,Physiotherapy,Educational...
# 4            Vocational training,Employment assistance
# ..                                                 ...
# 405                               Housing,Accomodation
# 406                               Housing,Accomodation
# 407                               Housing,Accomodation
# 408                               Housing,Accomodation
# 409  Housing,Accomodation,Peer support,Social Suppo...
#
#                                            Scheme Type  \
# 0                                    Low Income,Family
# 1                                Low Income,Healthcare
# 2                                      Low Income,Food
# 3    Disability,Family,Transport,Healthcare,Mental ...
# 4                         Prison and Ex-offenders,Work
# ..                                                 ...
# 405                                   Homeless,Housing
# 406                                   Homeless,Housing
# 407                                   Homeless,Housing
# 408                                   Homeless,Housing
# 409                     Housing,Mental Health,Children
#
#                                     search_booster(WL)  \
# 0    social service, individuals, families, casewor...
# 1                         See doctor, cancer, oncology
# 2    Needs help to get food, meal, hungry, have not...
# 3    rehabilitation, occupational therapy, physioth...
# 4    ex-convict need job, ex-convict skills trainin...
# ..                                                 ...
# 405  Homeless, no place to stay, runaway from home,...
# 406  Homeless, no place to stay, runaway from home,...
# 407  Homeless, no place to stay, runaway from home,...
# 408  Homeless, no place to stay, runaway from home,...
# 409  caregiving, caring, intellectual disability, I...
#
#                                               Combined  \
# 0    Information relating to social service and ref...
# 1    Cancer treatment can place a heavy financial b...
# 2    A self setup group which distributes meal box ...
# 3    Provides Occupational Therapy, Physiotherapy a...
# 4    We prepare educational programs (IT Training) ...
# ..                                                 ...
# 405  A seven-storey building with a 250-bed capacit...
# 406  A three-storey building with a 200-bed capacit...
# 407  A seven-storey building with a 200-bed capacit...
# 408  A four-storey building with a 250-bed capacity...
# 409  Designed to provide professional care, accommo...
#
#                                         Tags_tokenized
# 0    [information, relate, social, service, referra...
# 1    [cancer, treatment, place, heavy, financial, b...
# 2    [self, setup, group, distribute, meal, box, lo...
# 3    [provide, occupational, therapy, physiotherapy...
# 4    [prepare, educational, program, training, offe...
# ..                                                 ...
# 405  [seven, storey, building, 250, bed, capacity, ...
# 406  [storey, building, 200, bed, capacity, cater, ...
# 407  [seven, storey, building, 200, bed, capacity, ...
# 408  [storey, building, 250, bed, capacity, residen...
# 409  [design, provide, professional, care, accommod...
#
# [410 rows x 12 columns]

# %%
Description_to_match = df_schemes['Tags_tokenized']
Description_to_match[0:5]
# Out:
# 0    [information, relate, social, service, referra...
# 1    [cancer, treatment, place, heavy, financial, b...
# 2    [self, setup, group, distribute, meal, box, lo...
# 3    [provide, occupational, therapy, physiotherapy...
# 4    [prepare, educational, program, training, offe...
# Name: Tags_tokenized, dtype: object

# %%
#Word Cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

series = pd.Series(np.concatenate(Description_to_match)).value_counts()[:100]
wordcloud = WordCloud(background_color='white').generate_from_frequencies(series)

plt.figure(figsize=(15,15), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#build word dictionary

from gensim import corpora

#creating term dictionary
# %time dictionary = corpora.Dictionary(Description_to_match)

#filter out terms which occurs in less than 4 documents and more than 20% of the documents.
#NOTE: Since we have smaller dataset, we will keep this commented for now.

#dictionary.filter_extremes(no_below=4, no_above=0.2)

#list of few which which can be further removed
stoplist = set('hello and if this can would should could tell ask come go')
stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
dictionary.filter_tokens(stop_ids)
dictionary.save('dictionary')
# Out:
# Wall time: 22 ms

# %%
#print top 50 items from the dictionary with their unique token-id
dict_tokens = [[[dictionary[key], dictionary.token2id[dictionary[key]]] for key, value in dictionary.items() if key <= 50]]
print (dict_tokens)
# Out:
# [[['appropriate', 0], ['casework', 1], ['counsel', 2], ['counselling', 3], ['family', 4], ['groupwork', 5], ['individual', 6], ['information', 7], ['referral', 8], ['relate', 9], ['service', 10], ['social', 11], ['therapeutic', 12], ['365cps', 13], ['aid', 14], ['burden', 15], ['cancer', 16], ['daily', 17], ['doctor', 18], ['educate', 19], ['emotional', 20], ['financial', 21], ['find', 22], ['health', 23], ['heavy', 24], ['help', 25], ['immunity', 26], ['improve', 27], ['income', 28], ['low', 29], ['meet', 30], ['member', 31], ['need', 32], ['oncology', 33], ['oneís', 34], ['patient', 35], ['place', 36], ['provide', 37], ['support', 38], ['treatment', 39], ['box', 40], ['bukit', 41], ['child', 42], ['citizen', 43], ['day', 44], ['distribute', 45], ['eat', 46], ['flat', 47], ['food', 48], ['group', 49], ['hungry', 50]]]

# %%
#Bag of words
corpus = [dictionary.doc2bow(desc) for desc in Description_to_match]
word_frequencies = [[(dictionary[id], frequency) for id, frequency in line] for line in corpus[0:3]]
print(word_frequencies)
# Out:
# [[('appropriate', 1), ('casework', 2), ('counsel', 1), ('counselling', 1), ('family', 1), ('groupwork', 1), ('individual', 1), ('information', 1), ('referral', 1), ('relate', 1), ('service', 3), ('social', 2), ('therapeutic', 1)], [('family', 1), ('365cps', 1), ('aid', 1), ('burden', 1), ('cancer', 3), ('daily', 1), ('doctor', 1), ('educate', 1), ('emotional', 1), ('financial', 1), ('find', 1), ('health', 1), ('heavy', 1), ('help', 1), ('immunity', 1), ('improve', 1), ('income', 1), ('low', 1), ('meet', 1), ('member', 1), ('need', 1), ('oncology', 1), ('oneís', 1), ('patient', 2), ('place', 2), ('provide', 1), ('support', 1), ('treatment', 1)], [('help', 1), ('income', 1), ('low', 1), ('need', 1), ('box', 1), ('bukit', 1), ('child', 1), ('citizen', 1), ('day', 1), ('distribute', 1), ('eat', 1), ('flat', 1), ('food', 2), ('group', 1), ('hungry', 1), ('meal', 2), ('merah', 1), ('near', 1), ('needs', 1), ('needy', 1), ('operate', 1), ('region', 1), ('rented', 1), ('reside', 1), ('resident', 1), ('room', 1), ('self', 1), ('senior', 1), ('setup', 1)]]

# %%
#TF IDF and LSI
# %time schemes_tfidf_model = gensim.models.TfidfModel(corpus, id2word=dictionary)
schemes_tfidf_model.save("tfidf.model")
# %time schemes_lsi_model = gensim.models.LsiModel(schemes_tfidf_model[corpus], id2word=dictionary, num_topics=300)
schemes_lsi_model.save("lsi.model")
# Out:
# Wall time: 11 ms
# Wall time: 909 ms

# %%
# %time gensim.corpora.MmCorpus.serialize('schemes_tfidf_model_mm', schemes_tfidf_model[corpus])
# %time gensim.corpora.MmCorpus.serialize('schemes_lsi_model_mm',schemes_lsi_model[schemes_tfidf_model[corpus]])
# Out:
# Wall time: 109 ms
# Wall time: 618 ms

# %%
#Load indexed corpus
schemes_tfidf_corpus = gensim.corpora.MmCorpus('schemes_tfidf_model_mm')
schemes_lsi_corpus = gensim.corpora.MmCorpus('schemes_lsi_model_mm')

print(schemes_tfidf_corpus)
print(schemes_lsi_corpus)
# Out:
# MmCorpus(410 documents, 2796 features, 13418 non-zero entries)
# MmCorpus(410 documents, 300 features, 123000 non-zero entries)

# %%
from gensim.similarities import MatrixSimilarity

# %time schemes_index = MatrixSimilarity(schemes_lsi_corpus, num_features = schemes_lsi_corpus.num_terms)
# Out:
# Wall time: 279 ms

# %%
#Search similarity

from operator import itemgetter

def search_similar_schemes(search_term):
    query_bow = dictionary.doc2bow(spacy_tokenizer(search_term))
    query_tfidf = schemes_tfidf_model[query_bow]
    query_lsi = schemes_lsi_model[query_tfidf]

    schemes_index.num_best = 50

    schemes_list = schemes_index[query_lsi]

    schemes_list.sort(key=itemgetter(1), reverse=True)
    schemes_names = []

    for j, scheme in enumerate(schemes_list):

        schemes_names.append (
            {
                'Relevance': round((scheme[1] * 100),2),
                'Scheme Title': df_schemes['Scheme'][scheme[0]],
                'Description': df_schemes['Description'][scheme[0]]
            }

        )
        if j == (schemes_index.num_best-1):
            break

    return pd.DataFrame(schemes_names, columns=['Relevance','Scheme Title','Description'])

# %%
search_similar_schemes('pregnant teen')
# Out:
#     Relevance                                       Scheme Title  \
# 0       78.08                                HCSA Dayspring SPIN
# 1       64.40                       Pregnancy Crisis and Support
# 2       51.87          Babes - A Helping Hand for Pregnant Teens
# 3       36.13                                         Safe Place
# 4       29.05                                        Information
# 5        7.72                           Casework and Counselling
# 6        5.96             Evergreen Place, Home@Hong San (SASCO)
# 7        3.22                         Sexual Assualt Care Centre
# 8        3.16                        HIV+ Pregnant Mothers' Fund
# 9        3.15                                           The Tent
# 10       2.70                    Caregivers Training Grant (CTG)
# 11       2.58  PAVE Integrated Services for Individual and Fa...
# 12       2.53                          Singapore Hospice Council
# 13       2.49                                    Family services
# 14       2.35      THK Centre for Family Harmony (CFH) @ Circuit
# 15       2.32                     PSALT Care Peer Support Groups
# 16       2.29              Ahuva Good Shepherd ñ Childrenís Home
# 17       2.16                        Children and youth services
# 18       2.10                                   Various services
# 19       2.09                                     Emergency Fund
# 20       2.08                                     Project LADDER
# 21       1.97                     Geylang East Home for the Aged
# 22       1.96  Transport Subsidy and Assistive Device & Equip...
# 23       1.92    Good Samaritans Reintegration Assistance Scheme
# 24       1.90                       THK Care Close to Home (C2H)
# 25       1.82                                   Various Services
# 26       1.82                                APSN Tanglin School
# 27       1.78  Financial Assistance and Food on the Table Pro...
# 28       1.77                         Fei Yue Community Services
# 29       1.73  Aged Psychiatry Community Assessment and Treat...
# 30      -1.71                               Transitional Shelter
# 31      -1.76        HCSA Dayspring Residential Treatment Centre
# 32      -1.83                        St. Andrewís Cathedral Home
# 33      -1.88                          Marriage Support Services
# 34      -1.96                                            Tuition
# 35      -1.97  Subsidies for Government-Funded Intermediate a...
# 36      -1.97                                 THK Young at Heart
# 37      -2.11                      THK Home for Disabled @ Eunos
# 38      -2.14                    Paddy Chew Patient Welfare Fund
# 39      -2.17                                  MINDS Care Circle
# 40      -2.18                                The Children's Home
# 41      -2.26                                   Elderly services
# 42      -2.26                                  Yellow Brick Road
# 43      -2.27                           APSN Student Care Centre
# 44      -2.29                              SINDA Job Care Scheme
# 45      -2.30                                     Parenting Pact
# 46      -2.30                                    Compassion Fund
# 47      -2.31                                     Assisi Hospice
# 48      -2.33                      PERTAPIS Senior Citizens Home
# 49      -3.38                                           Casework
#
#                                           Description
# 0   SPIN empowers single parents to make informed ...
# 1   For emotional support, guidance, help and refe...
# 2   Staff will discuss the various options availab...
# 3   Safe Place provides timely, non-judgmental and...
# 4   Information on various issues, including contr...
# 5   PPIS serves clients who face marital issues, f...
# 6   A shelter or community home provides:\nFinanci...
# 7   The Care Centre provides safe, free and confid...
# 8   Assistance for HIV positive mothers who cannot...
# 9   Serves teenage girls (11-19 yrs) who :\n\ncome...
# 10  Helps caregivers defray the cost of attending ...
# 11  PAVE is an integrated service for family viole...
# 12  An umbrella body representing organisations th...
# 13  Casework management and counselling including ...
# 14  THK CFH @ Circuit provides the following servi...
# 15  PSALT Care Ltd (pronounced as ëSalt-careí), is...
# 16  Ahuva Good Shepherd ñ Childrenís Home was set ...
# 17  Children and youth services, particularly for ...
# 18  Looks after the needs of the migrants in Singa...
# 19  Disburses money to assist low-income individua...
# 20  Project LADDER reaches out to families of inma...
# 21  Our Sheltered Home was established in 1978 to ...
# 22  Members are provided up to 100% subsidy on a c...
# 23  Call-in/drop-in centre providing Counselling, ...
# 24  THK Care Close to Home (C2H) Programme support...
# 25  Befriending services for families of inmates, ...
# 26  APSN Tanglin Schoolís curriculum aims to engag...
# 27  The objective of the Financial Assistance & Fo...
# 28  Fei Yue provides services including counsellin...
# 29  APCATS is delivered through a multidisciplinar...
# 30  It aims to provide temporary accommodation to ...
# 31  Therapeutic Group Home service model for teena...
# 32  St Andrew's Cathedral Home runs a residential ...
# 33  The Marriage Support Services is made up of a ...
# 34                      Free tuition to youth-at-risk
# 35  Subsidies for those who may be eligible for in...
# 36  THK Young at Heart was set up to cater to seni...
# 37  THK Home for Disabled @ Eunos aims to develop ...
# 38  AFAís longest-running medications subsidy to p...
# 39  A safe community for caregivers of persons wit...
# 40  Chen Su Lan Methodist Children's Home (CSLMCH)...
# 41  Suicide intervention, befriender services, han...
# 42  Childrenís Society works with the caregivers a...
# 43  APSN provides before and after school care pro...
# 44  SINDAís Job Care Scheme (SINDA JCS) is to assi...
# 45  PPIS serves clients who face marital issues, f...
# 46  Assist students whose families are in crisis, ...
# 47  Provides compassionate, personalised and quali...
# 48  To meet the demands of destitute elderly regar...
# 49  Casework management for those facing financial...

# %%
import flask
print(flask.__version__)
# Out:
# 1.1.2

# %%
import pickle
print(pickle.format_version)
# Out:
# 4.0
